# %% [markdown]
# ## Importing relevant libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Plotting the function

# %%
def get_plot(classical_expectation, quantum_expectation):
    # Function to generate the comparison plot
    
    # Create tick labels for the x-axis
    tick_labels = ['No DD', 'Hahn-X', 'Hahn-Y', 'CP', 'CPMG', 'XYXY', 'YZYZ', 'XZXZ', 'CDD', 'XY8', 'XY16', 'Uhrig-X', \
                   'Uhrig-Y', 'KDD']

    # Setting plot dimensions
    f = plt.figure(dpi = 150)
    f.set_figwidth(15)
    f.set_figheight(4)

    # Set custom tick labels
    plt.xticks(range(len(tick_labels)), tick_labels)

    # Plot 
    plt.scatter(range(len(tick_labels)), quantum_expectation, marker = 'D', color = 'blue', label = 'VQSVD results')
    plt.scatter(range(len(tick_labels)), [classical_expectation] * len(tick_labels), marker = 'o', \
                color = 'red', label = 'Classical result')

    plt.xlabel('DD sequences', fontsize = 17)
    plt.ylabel(r"$\langle x^2 \rangle$", fontsize = 17)
    plt.title('COMPARISON BETWEEN THE VALUES OF' r'$~\langle x^2 \rangle$', fontsize = 15)

    plt.legend(loc = 'center')
    plt.grid(True) # add grid lines

    plt.show()

# %% [markdown]
# ## Test case 1: IBM Kyoto

# %%
# Get the classical expectation value
classical_expectation = 17.429012265966286

# Get the quantum expectation values
quantum_expectation = [17.437216076817627, 17.339222453576976, 17.339222453576976, 17.437216076817627, 17.437216076817627, \
                       17.437216076817627, 17.437216076817627, 17.437216076817627, 17.437216076817627, 17.437216076817627, \
                       17.437216076817627, 17.437216076817627, 17.437216076817627, 17.437216076817627]

# Plot
get_plot(classical_expectation, quantum_expectation)

# %% [markdown]
# ## Test case 1: IBM Lagos

# %%
# Get the classical expectation value
classical_expectation = 17.429012265966286

# Get the quantum expectation values
quantum_expectation = [17.363585987194682, 17.363585987194682, 17.363585987194682, 17.403487203708703, 17.403487203708703, \
                      17.403487203708703, 17.403487203708703, 17.403487203708703, 17.403487203708703, 17.403487203708703, \
                      17.403487203708703, 17.403487203708703, 17.403487203708703, 17.403487203708703]

# Plot
get_plot(classical_expectation, quantum_expectation)

# %% [markdown]
# ## Test case 1: IBM Nairobi

# %%
# Get the classical expectation value
classical_expectation = 17.429012265966286

# Get the quantum expectation values
quantum_expectation = [17.363585987194682, 17.35835243597303, 17.35835243597303, 17.332755744738016, 17.332755744738016, \
                      17.332755744738016, 17.332755744738016, 17.332755744738016, 17.332755744738016, 17.332755744738016, \
                      17.332755744738016, 17.332755744738016, 17.332755744738016, 17.403487203708703]

# Plot
get_plot(classical_expectation, quantum_expectation)

# %% [markdown]
# ## Test case 1: IBM Perth

# %%
# Get the classical expectation value
classical_expectation = 17.429012265966286

# Get the quantum expectation values
quantum_expectation = [17.605264331587932, 17.37962189526252, 17.37962189526252, 17.605264331587932, 17.605264331587932, \
                      17.605264331587932, 17.605264331587932, 17.605264331587932, 17.605264331587932, 17.605264331587932, \
                      17.605264331587932, 17.605264331587932, 17.605264331587932, 17.605264331587932]

# Plot
get_plot(classical_expectation, quantum_expectation)

# %% [markdown]
# ## Test case 2: IBM Kyoto

# %%
# Get the classical expectation value
classical_expectation = 54.96150379623784

# Get the quantum expectation values
quantum_expectation = [51.81880337286655, 51.76223277480956, 51.76223277480956, 51.732321026503975, 51.81880337286655, \
                      51.732321026503975, 51.81880337286655, 51.81880337286655, 51.732321026503975, 51.81880337286655, \
                      51.732321026503975, 51.81880337286655, 51.74819528044904, 51.74819528044904]

# Plot
get_plot(classical_expectation, quantum_expectation)

# %% [markdown]
# ## Test case 2: IBM Lagos

# %%
# Get the classical expectation value
classical_expectation = 54.96150379623784

# Get the quantum expectation values
quantum_expectation = [51.88634650148309, 51.84367247726853, 51.84367247726853, 52.44016508644573, 52.44016508644573, \
                      52.44016508644573, 52.44016508644573, 52.44016508644573, 52.44016508644573, 52.44016508644573, \
                      52.44016508644573, 52.44016508644573, 52.44016508644573, 52.44016508644573]

# Plot
get_plot(classical_expectation, quantum_expectation)

# %% [markdown]
# ## Test case 2: IBM Nairobi

# %%
# Get the classical expectation value
classical_expectation = 54.96150379623784

# Get the quantum expectation values
quantum_expectation = [51.88634650148309, 51.84367247726853, 51.84367247726853, 52.44016508644573, 52.44016508644573, \
                      52.44016508644573, 51.29446272631974, 52.44016508644573, 52.44016508644573, 52.44016508644573, \
                      52.44016508644573, 52.44016508644573, 52.44016508644573, 52.44016508644573]

# Plot
get_plot(classical_expectation, quantum_expectation)

# %% [markdown]
# ## Test case 2: IBM Perth

# %%
# Get the classical expectation value
classical_expectation = 54.96150379623784

# Get the quantum expectation values
quantum_expectation = [51.84367247726853, 51.84367247726853, 51.84367247726853, 51.88634650148309, 51.88634650148309, \
                      51.88634650148309, 51.88634650148309, 51.88634650148309, 51.29446272631974, 51.88634650148309, \
                      51.29446272631974, 51.88634650148309, 51.88634650148309, 51.29446272631974]

# Plot
get_plot(classical_expectation, quantum_expectation)

# %% [markdown]
# ## a < 0; IBM Brisbane

# %%
# Get the classical expectation value
classical_expectation = 138.56094953813795

# Get the quantum expectation values
quantum_expectation = [135.6442187796573, 137.34195629391465, 137.34195629391465, 135.6442187796573, 135.6442187796573, \
                      135.6442187796573, 135.6442187796573, 135.5947372382923, 135.6442187796573, 135.6442187796573, \
                      135.6442187796573, 135.6442187796573, 135.6442187796573, 135.6442187796573]

# Plot
get_plot(classical_expectation, quantum_expectation)
