# %% [markdown]
# ## Importing relevant libraries

# %%
import numpy as np
import scipy as sp
import scipy.linalg as la
import scipy.spatial as spat
from scipy.stats import unitary_group
from scipy.stats import moment
from scipy.stats import skew, kurtosis
from scipy.optimize import curve_fit
from scipy.linalg import norm
import matplotlib.pyplot as plt
import math
import itertools
from collections import Counter
import matplotlib.pyplot as plt
from qiskit import *
from qiskit import execute
from qiskit import transpiler
from qiskit import QuantumCircuit
from qiskit.circuit.add_control import add_control
from qiskit.extensions import UnitaryGate
from qiskit.circuit.reset import Reset
from qiskit_ibm_provider import IBMProvider
from qiskit.circuit.library.standard_gates import IGate, UGate, U3Gate
from qiskit.dagcircuit import DAGOpNode, DAGInNode
from qiskit.quantum_info.operators.predicates import matrix_equal
from qiskit.quantum_info.synthesis import OneQubitEulerDecomposer
from qiskit.transpiler.passes.optimization import Optimize1qGates
from qiskit.transpiler.basepasses import TransformationPass
from qiskit.transpiler.exceptions import TranspilerError
from math import fsum
from scipy.optimize import minimize
from qiskit.transpiler import PassManager, InstructionDurations
from qiskit.converters import circuit_to_dag, dag_to_circuit
from qiskit.dagcircuit import DAGCircuit
from qiskit.providers.models import BackendConfiguration
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel
from qiskit.transpiler.passes import BasisTranslator
from qiskit import QuantumCircuit, IBMQ, transpile
from qiskit.circuit import Delay
from qiskit.circuit.library import XGate, YGate, ZGate, RXGate, RYGate, RZGate
from qiskit.transpiler.passes import ALAPSchedule
from qiskit.circuit.equivalence_library import SessionEquivalenceLibrary
from qiskit.visualization import plot_histogram
from qiskit.visualization import timeline_drawer
from qiskit.providers.ibmq.managed import IBMQJobManager
from qiskit.providers.aer import AerSimulator

# Import Paddle libraries
import paddle
from paddle_quantum.ansatz import Circuit
from paddle_quantum.linalg import dagger
# Out:
# C:\Users\abc\anaconda3\lib\site-packages\openfermion\hamiltonians\hartree_fock.py:11: DeprecationWarning: Please use `OptimizeResult` from the `scipy.optimize` namespace, the `scipy.optimize.optimize` namespace is deprecated.
#   from scipy.optimize.optimize import OptimizeResult
# C:\Users\abc\anaconda3\lib\site-packages\paddle\tensor\creation.py:125: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if data.dtype == np.object:
# C:\Users\abc\anaconda3\lib\site-packages\paddle\tensor\creation.py:125: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if data.dtype == np.object:

# %% [markdown]
# ## Saving IBMQ account

# %%
IBMQ.save_account('20679dd22551941f9255655deabc9d69d569091c01ec92bdb01c2999ac7c55e771b66be79444a46d21a51f3a6894c01f6485b9692ef9d620849186b8e67964cf')

# %% [markdown]
# ## Loading IBMQ account

# %%
IBMQ.load_account()

# %% [markdown]
# ## Importing IBMQ provider

# %%
provider = IBMQ.get_provider('ibm-q')

# %% [markdown]
# ## Implementation of the classical subroutine
#
# ### Note: This constructs the Hermitian form of the Fokker-Planck matrix and defines additional functions for subsequent analysis of the zeromode

# %%
## Classical implementation
"""
Purpose: 
    Find the analytical solution given the input parameters
Input: 
    x: array representing the x coordinates over which the solution is to be found
    a, Γ: parameters for the Ornstein-Uhlenbeck equation
Output:
    y: array of the value of the analytical solution over x
"""

def OrnsteinUhlenbeck(x, a = 1, gamma = 1):
    y = np.sqrt(a/(2*np.pi*gamma)) * np.exp((-a * x ** 2)/(2*gamma))
    
    return y

"""
Purpose:
    Calculate the weighted Hermite polynomials using recursive relations up to H_n
Input:
    n: the highest number of Hermite polynomials to be evaluated at
    x: the value of x at which the weighted Hermite polynomials are to be evaluated
Output:
    Hermite: the value of the weighted Hermite polynomials
Example: HermiteSeries(2, 4) -> [H_0(4), H_1(4), H_2(4)]
"""

def HermiteSeries(n, x):
    Hermite = np.zeros((1, n+1))
    Hermite[0][0] = 1.0 * np.exp(-x**2/2)
    Hermite[0][1] = 2.0 * x *np.exp(-x**2/2)
    
    for ni in range(1, n):
        Hermite[0][ni+1] = 2*x*Hermite[0][ni] - 2*ni*Hermite[0][ni-1]
    
    return Hermite

"""
Purpose:
    Reconstruct the functions represented by the coefficients of weighted Hermite polynomials in spatial coordinates
Input:
    x: array containing the x values over which the function is to be evaluated
    coefficients: the coefficients corresponding to the Hermite polynomials (should be zero-mode of the operator)
    nmax: the highest order of weighted Hermite polynomials used
    s: the scaling factor
Output:
    y: the reconstruction
"""

def project(x, coefficients, nmax, s):
    
    y = np.zeros(x.shape)
    
    for i in (range(len(x))):
        x0 = s*x[i]
        hermite_values = HermiteSeries(nmax, x0)
        y[i] += np.dot(hermite_values, coefficients)
        
    return (x, y)

"""
Purpose:
    Normalize the PDF so that the area under the curve is 1
Input:
    x, y: arrays representing the unnormalized
Output:
    (x, y): normalized PDF
"""

def normalize(x, y):
    dx = x[1] - x[0]
    sum = 0
    
    for i in range(len(x)):
        sum = sum + (y[i] * dx)
    
    y = y/sum
    
    return (x, y)

"""
Purpose:
    Calculate the RMS
Input:
    y_op, y: the y values generated by the operator and the analytical solution
Output:
    RMS
"""

def rms_diff(y_op, y):
    return np.sqrt(np.sum((y_op-y)**2)/len(y))

"""
Purpose:
    Find s given a and Γ such that the projection in Hermite space is just H_0
Input:
    a, Γ: parameters for Ornstein-Uhlenbeck
Output:
    s
"""

def special_s(a, gamma):
    return np.sqrt(a/gamma)

def euler_representation(z):
    A = abs(z)
    phase = math.atan(z.imag/z.real)
    
    return A, phase

def generate_positive_semidefinite_matrix(eigenvalues):
    ## Function to transform the FPE operator to the Hermite basis and return a finite truncated matrix for the ...
    ## ... FPE operator
    
    n = len(eigenvalues)
    s = np.diag(eigenvalues)
    q, _ = la.qr(np.random.rand(n, n))
    semidef = np.dot(np.transpose(q), s)
    semidef = np.dot(semidef, q)
    
    return semidef

def normalize_probability(y, dx):
    ## Function to return a normalized PDF 
    
    total = np.sum(y) * dx
    y = y / total
    
    return y

def perturbed_ornstein_uhlenbeck(x0, a = 1, gamma = 1, c = 0, shift = 0):
    ## Function to compute the exact solution to the perturbed Ornstein-Uhlenbeck equation
    
    assert len(x0) > 1, "Error: x0 should be a vector"

    x = x0 - shift
    y = np.exp(-a*x**2 /(2*gamma) - c*x**4 /(4*gamma))
    dx = x[2] - x[1]
    
    y = normalize_probability(y, dx)
    
    return y

def special_L(a, gamma):
    ## Function to compute the characteristic length scale
    
    return np.sqrt(a/gamma)

def delta(N, n):
    ## Function to implement the Kronecker delta function
    
    if N == n:
        return 1
    else:
        return 0

def f(N,n):
    return 0.5*( np.sqrt(n*(n-1))*delta(N,n-2) + delta(N,n) - np.sqrt((n+1)*(n+2))*delta(N,n+2))

def g(N,n, L):
    return 0.5*L**2*( np.sqrt(n*(n-1))*delta(N,n-2) - (2*n+1)*delta(N,n) + np.sqrt((n+1)*(n+2))*delta(N,n+2))

def t(N, n, L):
    val1 = np.sqrt(n*(n-1)*(n-2)*(n-3))*delta(N, n-4)
    val2 = (2*n+2)*np.sqrt(n*(n-1))*delta(N, n-2)
    val3 = (6*n+3)*delta(N, n)
    val4 = -2*n*np.sqrt((n+1)*(n+2))*delta(N, n+2)
    val5 = -1*np.sqrt((n+1)*(n+2)*(n+3)*(n+4))*delta(N, n+4)

    return 1/(4*L**2)*( val1 + val2 + val3 + val4 + val5 )

def element_perturbed(N, n, L, a, c, gamma):
    ## Function to compute the matrix elements of the finite truncated matrix for the FPE operator (in the Hermite basis)
    
    return -(a*f(N,n) + c*t(N, n, L) + gamma*g(N, n, L))

def create_operator_perturbed(nmax, L, a, c, gamma):
    ## Function to generate the FPE operator matrix in the Hermite basis
    op = np.zeros((nmax+1, nmax+1))
    
    for N in range(nmax+1):
        row = N
        for n in range(nmax+1):
            col = n
            op[row, col] = element_perturbed(N, n, L, a, c, gamma)
    
    """
    if np.any(np.nan, op):
        print("There's an nan in the operator")
    elif np.any(np.inf, op):
        print("There is an inf in the operator")
    """

    return op

def state_n(nmax, x0, L):
    ## Function to compute the Hermite polynomials upto the order specified by nmax
    
    assert L > 0, "Error (state_n): input L must be greater than or equal to 0"

    states = np.zeros(nmax + 1)
    x = x0*L

    states[0] = np.sqrt(L*np.sqrt(1/np.pi))* 1.0 * np.exp(-x**2/2)

    if nmax > 0:
        states[1] = np.sqrt(L*np.sqrt(1/np.pi))* (1/np.sqrt(2)) * 2.0 * x * np.exp(-(x**2)/2)
    
    for ni in range(2, nmax + 1):
        states[ni] = ((np.sqrt(2)*x) / np.sqrt(ni))*states[ni-1] - (ni-1)/np.sqrt((ni)*(ni-1))*states[ni-2]

    return states

def integrate_eigenvector(x0, y, nmax, L):
    ## Function to compute the coefficients corresponding to the calculated Hermite polynomials by numerical integration
    ## Note: here, we use the left-hand integration method
    
    dx = x0[2] - x0[1]
    eigenvector = np.zeros(nmax + 1)

    for i in range(len(x)):

        states = state_n(nmax, x0[i], L)
        states = states * y[i] * dx

        eigenvector = eigenvector + states
        
    return {"eigenvector" : eigenvector, "dx" : dx, "nmax" : nmax, "x0" : x0, "L" : L}

def make_operator_even(op):
    op_new = np.zeros((op.shape[0]//2, op.shape[1]//2))
    
    for row in range(op_new.shape[0]):
        for col in range(op_new.shape[1]):
            op_new[row, col] = op[row*2, col * 2]
    
    return op_new

def reconstruct_eigenvector(cache, normalize = True, only_even = False):
    ## Function to reconstruct the PDF using the cache obtained previously
    
    eigenvector = cache["eigenvector"]
    nmax = cache["nmax"]
    x0 = cache["x0"]
    dx = cache["dx"]
    L = cache["L"]
    
    if not only_even:
        eigenvector = cache["eigenvector"]
    else:
        eigenvector_old = cache["eigenvector"]
        eigenvector = np.zeros(nmax + 1)
        
        for i in range(len(eigenvector_old)):
            eigenvector[2*i] = eigenvector_old[i]

    y = np.zeros(len(x0))

    for i in range(len(x0)):
        states = state_n(nmax, x0[i], L)
        y[i] += (np.dot(states, eigenvector))
    if normalize:   
        y = normalize_probability(y, dx)
        
    return (x0, y)

def find_zeromode(op_nonhermitian, nmax, x0, dx, L, which = "single", only_even = False):
    ## Function to compute the zeromode, its position, and the eigenvalue corresponding to the zeromode
    
    assert which == "nonhermitian" or which == "single", "Error: currently only supports which = {\"nonhermitian\", \"single\"}"
    
    if only_even:
        op_processed = make_operator_even(op_nonhermitian)
    else:
        op_processed = op_nonhermitian
        
    if which == "nonhermitian":
        op = op_processed
    elif which == "single":
        op = np.dot(np.transpose(op_processed), op_processed)

    eigenvalues, eigenvectors = la.eig(op)

    index = np.argmin(np.real(eigenvalues)**2)

    min_eigenval = eigenvalues[index]
    
    zeromode = eigenvectors[:, index]

    return {"operator" : op, "which" : which, \
            "eigenvector" : np.real(zeromode), "index" : index, "eigenvalue" : np.real(min_eigenval), \
            "nmax" : nmax, "x0" : x0, "dx" : dx, "L" : L, "spectrum" : eigenvalues, "P" : eigenvectors}

def rms_diff(y0, y, sigdigits = 0):
    ## Function to compute the RMS difference between the analytically computed PDF and the one ...
    ## ... obtained using the FPE operator
    
    assert len(y0) == len(y), "Error: the length of y0 and y should be the same"
    diff = np.sum((y0-y)**2)/len(y0)
    
    return np.sqrt(diff)

def analyze_collapse(initial_state, P, index):
    num_basis = P.shape[1]
    coefficients = np.zeros((num_basis, ))

    for i in range(num_basis):
        basis = P[:, i]
        basis = normalize_eigenvector(basis)

        coefficients[i] = np.dot(basis, initial_state)

    normalized_coefficients = normalize_eigenvector(coefficients)

    reconstruction = np.zeros((P.shape[0], ))

    for i in range(num_basis):
        basis = P[:, i]
        basis = normalize_eigenvector(basis)

        added_vector = coefficients[i] * basis
        reconstruction = reconstruction + added_vector

    probability = normalized_coefficients ** 2
    
    probability_zeromode = probability[index]
    assert np.sum(probability) - 1 < 0.00001, "Error: unity normalization of probability is not observed"

    print("The initial_state is: ")
    print(initial_state)
    print()

    print("The coefficient expansion is: ")
    print(coefficients)
    print()

    print("The normalized coefficient expansion is: ")
    print(normalized_coefficients)
    print()

    print("The reconstructed vector is: ")
    print(reconstruction)
    print()

    print("The probability of collapsing into each eigenvector is: ")
    print(probability)
    print()

    print("The probability of collapsing into the zeromode is: ")
    print(probability_zeromode)
    print()
    
    return probability_zeromode, probability

def get_unitary(matrix, add_half = False):
    """
    Purpose: given a matrix, returns the unitary, hermitian matrix to be diagonalized
    Input: matrix -> the matrix to be diagonalized
    Output: U -> the unitary matrix
            nqubits -> the number of qubis needed to represent the basis of U
            dimension -> the dimension of the original matrix
    """
    assert matrix.ndim == 2, "Error: Only a matrix maybe processed"
    assert matrix.shape[0] == matrix.shape[1], "Error: Only a square matrix maybe processed"

    if np.any(np.transpose(matrix) != matrix):
        matrix_T = np.transpose(matrix)
        matrix = np.dot(matrix_T, matrix)

    ## Finding the dimension of the matrix
    dimension_hermitian = matrix.shape[0]

    ## Finding the number of qubits required to represent the matrix
    nqubits = int(np.ceil(np.log2(dimension_hermitian)))

    ## Construct the relevant matrix
    op_dim = 2 ** nqubits
    op = np.eye(op_dim)
    op[0:dimension_hermitian, 0:dimension_hermitian] = np.copy(matrix)

    if add_half:
        op = op + np.pi * np.eye(op.shape[0])

    U = la.expm(1j*op)

    # Get the dimensions of the unitary matrix
    dimension = U.shape[0]

    return U, nqubits, dimension

# %% [markdown]
# ## Helper functions

# %%
def find_probability(eigenvector_raw):
    """
    Purpose: Find the probability associated with each basis of an eigenvector
    Input: eigenvector_raw -> Numpy array documenting the number of times each basis is detected within the eigenvector
    Output: eigenvector_prob -> Numpy array documenting the probability of detecting each basis
    """
    count_total = np.sum(eigenvector_raw)
    eigenvector_prob = eigenvector_raw / count_total
    
    return eigenvector_prob

def find_amplitude(eigenvector_prob):
    """
    Purpose: Finding the probability amplitude of each basis using quantum mechanics
    Input: eigenvector_prob -> Numpy array documenting the probability that each basis is measured
    Output: eigenvector -> Numpy array representing the eigenvector
    """
    eigenvector = np.sqrt(eigenvector_prob)
    return eigenvector

def normalize_eigenvector(vector):
    """
    Purpose: Normalizes a vector such that its norm is 1
    Input: vector -> The vector to be normalized
    Output: vector -> The normalized vector
    """
    L2 = np.sum(np.square(vector))
    vector = vector / np.sqrt(L2)

    return vector

def make_operator_even(op):
    op_new = np.zeros((op.shape[0]//2, op.shape[1]//2))

    for row in range(op_new.shape[0]):
        for col in range(op_new.shape[1]):
            op_new[row, col] = op[row*2, col * 2]

    return op_new

# %% [markdown]
# ## Computing the steady-state PDF

# %%
def get_pdf(n, x, dx, L, shift, zeromode_qpe, normalize = True, make_even = False):
    # Function to construct the ground state PDF using the VQSVD zeromode
    
    if not make_even:
        eigenvector = zeromode_qpe
    else:
        eigenvector_old = zeromode_qpe
        eigenvector = np.zeros(n + 1)
        for i in range(len(eigenvector_old)):
            eigenvector[2*i] = eigenvector_old[i]
            
    x0 = x - shift
    
    # Computing the PDF
    y = np.zeros(len(x0))

    for i in range(len(x0)):
        states = state_n(nmax, x0[i], L)
        y[i] += (np.dot(states, eigenvector))
    
    if normalize:
        y = normalize_probability(y, dx)

    return x0, y

# %% [markdown]
# ## Computing expectation values

# %%
def get_expectation(x, y):
    # Function to compute the expectation value of x and using the estimated ground state PDF
    # Note: Ground state PDF already normalized
    
    # Calculate expectation values
    expectation_x, expectation_x_square = 0, 0
    
    for x_val, pdf in zip(x, y):
        expectation_x += x_val * pdf
        expectation_x_square += x_val**2 * pdf
        
    return expectation_x, expectation_x_square

def expect_verify(x, y, n):
    # Function to verify if all odd order moments of the ground state PDF (symmetric about 0) vanish
    
    # Calculate expectation values
    expectation_val = 0
    
    for x_val, pdf in zip(x, y):
        expectation_val += x_val**n * pdf
        
    if n % 2 != 0:
        if expectation_val < 1e-10: # error tolerance applied is 1e-10
            return True
        else:
            return False
    else:
        return # else, if n is even, the function returns None

# %% [markdown]
# ## Computing PDF moments

# %%
def get_moments(y, moments):
    # Function to compute the moments of the ground state PDF (about the mean)
    
    # Initialization
    moment_vals = []
    
    for i in range(len(moments)):
        moment_val = moment(y, moments[i])
        moment_vals.append(moment_val)
        
    return moment_vals

# %% [markdown]
# ## Defining a cutoff and generating plots accordingly

# %%
def cutoff_graph(x, y, y_cutoff):
    # Function to obtain the bounded x and y values (PDF on the log scale)
    
    x_values = [x_val for x_val, y_val in zip(x, y) if y_val >= y_cutoff]
    y_values = [y_val for y_val in y if y_val >= y_cutoff]
    
    return x_values, y_values

# %% [markdown]
# ## Computing PDF maximas

# %%
def get_maxima(x, y):
    # Function to determine the maximas in the steady-state PDFs 
    
    # Extract the positive side of the PDF
    x_positive = [x_val for x_val in x if x_val >= 0]
    y_positive = [y_val for x_val, y_val in zip(x, y) if x_val >= 0]
    
    # Determine the maximum
    max_idx = np.argmax(y_positive)
    x_max = x_positive[max_idx]
    
    return x_max

# %% [markdown]
# # Classical and quantum analysis
#
# ## Constructing the FPE operator

# %%
# Defining parameters
nmax = 15
dx = 0.01
a = -5
gamma = 2
c = 3
L = 2
shift = 0

#3, 5, 1, 1
x = np.linspace(-10, 10, int((20)/dx))
y = perturbed_ornstein_uhlenbeck(x, a = a, gamma = gamma, c = c, shift = shift)

## Finding the zeromode through direct integration
cache_projection = integrate_eigenvector(x, y, nmax, L)
x_projection, y_projection = reconstruct_eigenvector(cache_projection)

## Finding the zeromode through diagonalization
op_nonhermitian = create_operator_perturbed(nmax, L, a, c, gamma)
only_even = True

cache_diagonalization = find_zeromode(op_nonhermitian, nmax, x, dx, L, which = "single", only_even = only_even)
x_diagonalization, y_diagonalization = reconstruct_eigenvector(cache_diagonalization, only_even = only_even)

## Moments array
moments = [1, 2, 3, 4, 5] # to compute the moments of the distribution(s)

# %% [markdown]
# ## Analysis of the diagonalization

# %%
num_basis = cache_diagonalization['P'].shape[1]
initial = np.zeros((num_basis, ))
initial[0] = 1
index = cache_diagonalization['index']

probability_zeromode, probability = analyze_collapse(initial, cache_diagonalization['P'], index)
# Out:
# The initial_state is:
# [1. 0. 0. 0. 0. 0. 0. 0.]
#
# The coefficient expansion is:
# [ 1.98960038e-05  7.07119051e-04 -7.72751374e-03  3.60311205e-02
#   1.28555530e-01 -4.29357506e-01  4.74477568e-01 -7.56728609e-01]
#
# The normalized coefficient expansion is:
# [ 1.98960038e-05  7.07119051e-04 -7.72751374e-03  3.60311205e-02
#   1.28555530e-01 -4.29357506e-01  4.74477568e-01 -7.56728609e-01]
#
# The reconstructed vector is:
# [ 1.00000000e+00 -9.16107468e-15 -2.77555756e-15  4.44089210e-16
#   1.05471187e-15  5.44703171e-16  2.08166817e-17 -1.89084859e-16]
#
# The probability of collapsing into each eigenvector is:
# [3.95850968e-10 5.00017353e-07 5.97144685e-05 1.29824164e-03
#  1.65265243e-02 1.84347868e-01 2.25128963e-01 5.72638188e-01]
#
# The probability of collapsing into the zeromode is:
# 0.22512896288738937

# %% [markdown]
# ## Loading the FPE operator

# %%
matrix = cache_diagonalization['operator']

# Defining the matrix to be diagonalized
U, n_query_qubits, dimension = get_unitary(matrix, add_half = False)

# Printing out the unitary matrix
print(U)
print(dimension)
# Out:
# [[ 6.25455376e-01+0.20987536j  5.35625725e-01-0.09656813j
#   -4.10829682e-02-0.09722243j -3.92089663e-01+0.0525435j
#   -2.75280537e-01+0.12435975j -3.97366009e-02+0.08133744j
#    3.11286566e-02+0.02215148j  3.05391652e-04+0.0017818j ]
#  [ 5.35625725e-01-0.09656813j -1.53348681e-02+0.03039333j
#    3.22319431e-01+0.13265506j  5.56422885e-01-0.14515154j
#    3.19709839e-02-0.26324632j -3.21918249e-01-0.19186183j
#   -1.88269518e-01-0.06489783j -2.83590382e-03-0.00546974j]
#  [-4.10829682e-02-0.09722243j  3.22319431e-01+0.13265506j
#    6.93668748e-01-0.08985757j  2.73501159e-02+0.08108148j
#    3.05278135e-01+0.01709207j  4.90234686e-01+0.10397248j
#    1.37075334e-01+0.05490283j -6.29434033e-02-0.02016967j]
#  [-3.92089663e-01+0.0525435j   5.56422885e-01-0.14515154j
#    2.73501159e-02+0.08108148j  3.82159248e-01+0.013039j
#   -6.04077151e-02+0.36360929j -3.75125593e-01-0.01282998j
#    1.43286582e-01-0.00609531j  2.17473136e-01+0.12117817j]
#  [-2.75280537e-01+0.12435975j  3.19709839e-02-0.26324632j
#    3.05278135e-01+0.01709207j -6.04077151e-02+0.36360929j
#   -3.66316072e-01-0.18987482j -1.08507294e-01+0.14420928j
#   -5.56001952e-01-0.02517785j -2.18610703e-01-0.22071253j]
#  [-3.97366009e-02+0.08133744j -3.21918249e-01-0.19186183j
#    4.90234686e-01+0.10397248j -3.75125593e-01-0.01282998j
#   -1.08507294e-01+0.14420928j -3.39111112e-01-0.32804865j
#    3.46969092e-01-0.01504519j -9.31832517e-02+0.27360432j]
#  [ 3.11286566e-02+0.02215148j -1.88269518e-01-0.06489783j
#    1.37075334e-01+0.05490283j  1.43286582e-01-0.00609531j
#   -5.56001952e-01-0.02517785j  3.46969092e-01-0.01504519j
#    1.80543474e-01-0.11457941j  6.46525572e-01-0.14968403j]
#  [ 3.05391652e-04+0.0017818j  -2.83590382e-03-0.00546974j
#   -6.29434033e-02-0.02016967j  2.17473136e-01+0.12117817j
#   -2.18610703e-01-0.22071253j -9.31832517e-02+0.27360432j
#    6.46525572e-01-0.14968403j -4.55881561e-01-0.32455453j]]
# 8

# %% [markdown]
# ## Exact diagonalization of the unitary matrix

# %%
## Classical diagnonalization
A, P = la.eig(U)

A_real = np.real(A)
index = np.where(A_real == np.amax(A_real))[0][0]

eigenvalue = A[index]
zeromode_classic = P[:, index]

zeromode_classic = np.real(normalize_eigenvector(zeromode_classic))
zeromode_classic = np.reshape(zeromode_classic, (zeromode_classic.size, 1))

print("the available eigenvalues are: \n" + str(A))
print()

## Printing relevant results
print("the available eigenvalues are: \n" + str(A))
print()

print("The minimum eigenvalue located is: \n" + str(eigenvalue))
print()

print("The minimum zeromode located is: \n" + str(np.real(zeromode_classic)))
print()

# Estimating the probability of collapse into the zeromode
initial = np.zeros((P.shape[0], ))
initial[0] = 1
    
probability_zeromode, probability = analyze_collapse(initial, np.real(P), index)

# Printing out the spectrum of eigenvectors
print('The spectrum of eigenvectors is:' )
print(P)
print()
# Out:
# the available eigenvalues are:
# [-0.80755541+0.58979171j -0.88033201-0.47435803j -0.55521883-0.83170431j
#   0.98211763+0.18826832j  0.99998353+0.00573967j  0.96739561-0.25327009j
#   0.99713211-0.0756806j  -0.99833939+0.05760604j]
#
# the available eigenvalues are:
# [-0.80755541+0.58979171j -0.88033201-0.47435803j -0.55521883-0.83170431j
#   0.98211763+0.18826832j  0.99998353+0.00573967j  0.96739561-0.25327009j
#   0.99713211-0.0756806j  -0.99833939+0.05760604j]
#
# The minimum eigenvalue located is:
# (0.9999835279417936+0.005739672880183965j)
#
# The minimum zeromode located is:
# [[ 0.47447757]
#  [ 0.60870008]
#  [ 0.55925952]
#  [ 0.29602839]
#  [ 0.03873082]
#  [-0.04625392]
#  [-0.01489072]
#  [ 0.00948653]]
#
# The initial_state is:
# [1. 0. 0. 0. 0. 0. 0. 0.]
#
# The coefficient expansion is:
# [-4.29357506e-01 -1.28555530e-01  7.07119051e-04  7.56728609e-01
#   4.74477568e-01 -7.72751374e-03  3.60311205e-02  1.98960038e-05]
#
# The normalized coefficient expansion is:
# [-4.29357506e-01 -1.28555530e-01  7.07119051e-04  7.56728609e-01
#   4.74477568e-01 -7.72751374e-03  3.60311205e-02  1.98960038e-05]
#
# The reconstructed vector is:
# [ 1.00000000e+00 -1.00036510e-15 -9.35193195e-17 -4.66769152e-16
#   4.40859473e-16  2.79349772e-16 -3.48709912e-16 -2.32336055e-16]
#
# The probability of collapsing into each eigenvector is:
# [1.84347868e-01 1.65265243e-02 5.00017353e-07 5.72638188e-01
#  2.25128963e-01 5.97144685e-05 1.29824164e-03 3.95850968e-10]
#
# The probability of collapsing into the zeromode is:
# 0.2251289628873802
#
# The spectrum of eigenvectors is:
# [[-4.29357506e-01-1.10236764e-15j -1.28555530e-01-1.81805014e-16j
#    7.07119051e-04+2.50954856e-16j  7.56728609e-01+0.00000000e+00j
#    4.74477568e-01+2.88989003e-16j -7.72751374e-03-4.53929516e-16j
#    3.60311205e-02+5.14211906e-16j  1.98960038e-05+4.74694978e-18j]
#  [ 5.28206016e-01+0.00000000e+00j  5.20829107e-01+6.24673938e-16j
#   -1.73919959e-02-2.75939381e-17j  2.00748536e-02-4.98528912e-16j
#    6.08700076e-01+0.00000000e+00j  9.16811243e-02+3.84443129e-15j
#   -2.64779870e-01+2.06446973e-15j  6.12336397e-04-1.12142119e-17j]
#  [ 5.94240978e-02+4.00183892e-16j -3.82595836e-01-4.39726312e-16j
#    1.05134366e-01-1.95369274e-16j -4.09182294e-01-7.99206382e-16j
#    5.59259524e-01-2.63400868e-15j -3.31248488e-01-8.53672057e-15j
#    4.98995368e-01-4.57300312e-15j -1.06143780e-02+2.05268785e-16j]
#  [-4.78997151e-01+9.53486172e-17j -1.11739972e-01-6.05948657e-16j
#   -3.21450066e-01-5.63432984e-17j -4.54974799e-01-1.25276587e-15j
#    2.96028394e-01-1.23111391e-15j  4.92680653e-01+8.67478613e-15j
#   -3.37454836e-01+3.59648018e-15j  5.91683478e-02-3.28021358e-17j]
#  [-5.06088331e-01-4.12686553e-16j  4.75891234e-01-3.13188102e-16j
#    4.98593790e-01+1.00923962e-16j -2.26993158e-01-5.49845960e-16j
#    3.87308202e-02+2.19974689e-17j -3.81203971e-01-2.01924949e-15j
#   -1.66891262e-01-1.06417956e-15j -2.06424892e-01-1.05257597e-16j]
#  [-2.15996512e-01-1.18951713e-16j  5.25636602e-01+0.00000000e+00j
#   -5.04927896e-01-4.33268228e-16j -2.80991682e-02+4.58980016e-17j
#   -4.62539209e-02-5.40259823e-16j -1.38432631e-01-6.40952549e-15j
#    4.80772976e-01-3.08991132e-15j  4.10930959e-01+1.39188496e-16j]
#  [-2.93160014e-02-1.91982527e-16j  2.23615548e-01+1.98870176e-16j
#    1.21004777e-01+6.49305086e-16j  1.09906165e-02-2.89810924e-17j
#   -1.48907154e-02-1.55030747e-15j  5.54260387e-01+0.00000000e+00j
#    5.30584387e-01+0.00000000e+00j -5.87730898e-01+2.79233110e-16j]
#  [-6.45941443e-03-9.04609392e-17j  2.39771551e-02-5.64727141e-17j
#    6.05907201e-01+0.00000000e+00j -9.50493015e-03-3.85290915e-16j
#    9.48652649e-03-6.89574222e-16j  4.09133760e-01+2.11592107e-15j
#    1.58764278e-01+7.27016245e-16j  6.62935117e-01+0.00000000e+00j]]

# %% [markdown]
# ## Exact diagonalization of the non-Hermitian FPE operator (needed for VQE simulations)

# %%
# Use only even-order Hermite polynomials
op_nonhermitian = make_operator_even(op_nonhermitian)

# Compute the non-Hermitian zeromode
A, P = sp.linalg.eig(op_nonhermitian)

A_real = np.real(A)
index = np.where(A_real == np.amin(A_real))[0][0]

eigenvalue = A[index]
zeromode_nonhermitian = P[:, index]

zeromode_nonhermitian = np.real(normalize_eigenvector(zeromode_nonhermitian))

## Printing results
print('The zeromode of the non-Hermitian FPE operator is:')
print(zeromode_nonhermitian)
print()
# Out:
# The zeromode of the non-Hermitian FPE operator is:
# [-0.47534817 -0.6097502  -0.55864412 -0.29374455 -0.03650569  0.04723728
#   0.01503059 -0.00947442]

# %% [markdown]
# ## Quantum (VQD) analysis

# %% [markdown]
# ### Importing relevant libraries

# %%
# Libraries for implementing the VQD algorithm
from qiskit.circuit import QuantumCircuit, Parameter
from qiskit.primitives import Sampler, Estimator
# from qiskit_ibm_runtime import QiskitRuntimeService, Estimator, Sampler, Session, Options
from qiskit.quantum_info.operators import Operator
from qiskit.quantum_info import SparsePauliOp
from qiskit.circuit.library import RealAmplitudes, TwoLocal, EfficientSU2
from qiskit.algorithms.optimizers import *
from qiskit.algorithms.state_fidelities import ComputeUncompute
from qiskit.algorithms.eigensolvers import EigensolverResult, VQD

# Import classical optimizers
from qiskit_algorithms.optimizers import SPSA, P_BFGS, COBYLA
# Out:
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:52: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.pauli_op.PauliOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   X = make_immutable(PauliOp(Pauli("X")))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\primitive_ops\pauli_op.py:54: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.primitive_op.PrimitiveOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   super().__init__(primitive, coeff=coeff)
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\primitive_ops\primitive_op.py:110: DeprecationWarning: The class ``qiskit.opflow.operator_base.OperatorBase`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   super().__init__()
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_base.py:53: DeprecationWarning: The class ``qiskit.opflow.mixins.star_algebra.StarAlgebraMixin`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   super().__init__()
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:52: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   X = make_immutable(PauliOp(Pauli("X")))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:53: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.pauli_op.PauliOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   Y = make_immutable(PauliOp(Pauli("Y")))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:53: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   Y = make_immutable(PauliOp(Pauli("Y")))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:54: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.pauli_op.PauliOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   Z = make_immutable(PauliOp(Pauli("Z")))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:54: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   Z = make_immutable(PauliOp(Pauli("Z")))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:55: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.pauli_op.PauliOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   I = make_immutable(PauliOp(Pauli("I")))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:55: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   I = make_immutable(PauliOp(Pauli("I")))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:58: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.circuit_op.CircuitOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   CX = make_immutable(CircuitOp(CXGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\primitive_ops\circuit_op.py:66: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.primitive_op.PrimitiveOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   super().__init__(primitive, coeff)
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:58: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   CX = make_immutable(CircuitOp(CXGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:59: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.circuit_op.CircuitOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   S = make_immutable(CircuitOp(SGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:59: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   S = make_immutable(CircuitOp(SGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:60: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.circuit_op.CircuitOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   H = make_immutable(CircuitOp(HGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:60: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   H = make_immutable(CircuitOp(HGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:61: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.circuit_op.CircuitOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   T = make_immutable(CircuitOp(TGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:61: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   T = make_immutable(CircuitOp(TGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:62: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.circuit_op.CircuitOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   Swap = make_immutable(CircuitOp(SwapGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:62: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   Swap = make_immutable(CircuitOp(SwapGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:63: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.circuit_op.CircuitOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   CZ = make_immutable(CircuitOp(CZGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:63: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   CZ = make_immutable(CircuitOp(CZGate()))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:66: DeprecationWarning: The class ``qiskit.opflow.state_fns.dict_state_fn.DictStateFn`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   Zero = make_immutable(DictStateFn("0"))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\state_fns\dict_state_fn.py:89: DeprecationWarning: The class ``qiskit.opflow.state_fns.state_fn.StateFn`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   super().__init__(primitive, coeff=coeff, is_measurement=is_measurement)
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\state_fns\state_fn.py:142: DeprecationWarning: The class ``qiskit.opflow.operator_base.OperatorBase`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   super().__init__()
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:66: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   Zero = make_immutable(DictStateFn("0"))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:67: DeprecationWarning: The class ``qiskit.opflow.state_fns.dict_state_fn.DictStateFn`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   One = make_immutable(DictStateFn("1"))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:67: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   One = make_immutable(DictStateFn("1"))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\state_fns\state_fn.py:250: DeprecationWarning: The class ``qiskit.opflow.state_fns.dict_state_fn.DictStateFn`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   temp = StateFn(
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\primitive_ops\circuit_op.py:137: DeprecationWarning: The class ``qiskit.opflow.state_fns.circuit_state_fn.CircuitStateFn`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   return CircuitStateFn(new_self.primitive, coeff=new_self.coeff)
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\state_fns\circuit_state_fn.py:83: DeprecationWarning: The class ``qiskit.opflow.state_fns.state_fn.StateFn`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   super().__init__(primitive, coeff=coeff, is_measurement=is_measurement)
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:68: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   Plus = make_immutable(H.compose(Zero))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\primitive_ops\primitive_op.py:292: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.circuit_op.CircuitOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   return CircuitOp(self.to_circuit(), coeff=self.coeff)
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\primitive_ops\circuit_op.py:149: DeprecationWarning: The class ``qiskit.opflow.primitive_ops.circuit_op.CircuitOp`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   return CircuitOp(new_qc, coeff=new_self.coeff * other.coeff)
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\opflow\operator_globals.py:69: DeprecationWarning: The function ``qiskit.opflow.operator_globals.make_immutable()`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   Minus = make_immutable(H.compose(X).compose(Zero))
# C:\Users\abc\anaconda3\lib\site-packages\qiskit\algorithms\evolvers\evolution_result.py:19: DeprecationWarning: The ``qiskit.opflow`` module is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   from qiskit.opflow import StateFn, OperatorBase
# C:\Users\abc\AppData\Local\Temp\ipykernel_10896\1345929692.py:8: DeprecationWarning: ``qiskit.algorithms`` has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. The ``qiskit.algorithms`` import path is deprecated as of qiskit-terra 0.25.0 and will be removed no earlier than 3 months after the release date. Please run ``pip install qiskit_algorithms`` and use ``import qiskit_algorithms`` instead.
#   from qiskit.algorithms.optimizers import *

# %% [markdown]
# ### Initialization

# %%
# Initialization of arrays for storing intermediate VQD results
counts_noisy, values_noisy, steps_noisy = [], [], []
counts_noiseless, values_noiseless, steps_noiseless = [], [], []

def callback_noisy(eval_count, params, value, meta, step):
    # Function to store intermediate values from VQD (noisy simulation)
    
    counts_noisy.append(eval_count)
    values_noisy.append(value)
    steps_noisy.append(step)
    
def callback_noiseless(eval_count, params, value, meta, step):
    # Function to store intermediate values from VQD (noisy simulation)
    
    counts_noiseless.append(eval_count)
    values_noiseless.append(value)
    steps_noiseless.append(step)

# %% [markdown]
# ### Running VQD

# %%
# Import Statevector and SparsePauliOp
from qiskit.quantum_info import SparsePauliOp, Statevector

# Import a fake backend and Qiskit simulators and/or noise libraries
from qiskit.providers.fake_provider import FakeMontreal, FakeMumbai, FakeWashington, FakeGuadalupe
from qiskit_aer import AerSimulator
from qiskit_aer.primitives import Estimator as AerEstimator 
from qiskit_aer.noise import NoiseModel

def run_VQD(matrix, k, RealAmps = True, bfgs = True, noise = True):
    # Function to implement the VQD algorithm
    
    dimension = matrix.shape[0]
    num_qubits = int(np.log2(dimension))
    
    # Define the qubit Hamiltonian
    qub_hamiltonian = SparsePauliOp.from_operator(matrix)
    
    # Define the circuit ansatz
    if RealAmps:
        ansatz = RealAmplitudes(num_qubits = num_qubits, reps = 4)
    else:
        ansatz = EfficientSU2(num_qubits = num_qubits, reps = 4)
    
    # Determine the number of variational parameters
    num_parameters = ansatz.num_parameters
    
    # Initialize the optimizer and the initial point
    initial_point = np.random.uniform(-np.pi, np.pi, ansatz.num_parameters)
    
    # Initializing the estimator, sampler, and fidelity
    estimator = Estimator()
    sampler = Sampler()
    fidelity = ComputeUncompute(sampler)
    
    # Get the classical optimizer
    if bfgs:
        optimizer = P_BFGS(maxfun = 1000)
    else:
        optimizer = SPSA(maxiter = 150)
    
    # Run the VQD simulation 
    if not noise: # if False, run a noiseless simulation
        vqd = VQD(estimator = estimator, fidelity = fidelity, ansatz = ansatz, optimizer = optimizer, \
                  k = k, initial_point = initial_point, callback = callback_noiseless)
        result = vqd.compute_eigenvalues(operator = qub_hamiltonian)
        
        # Get the corresponding zeromode
        optimal_params = result.optimal_points
        zeromode_points = optimal_params[0]
        final_circuit = ansatz.assign_parameters(zeromode_points)
        zeromode_vqd = Statevector.from_instruction(final_circuit)
        
    else: # if True, run a noisy simulation
        # Get the backend
        backend = provider.get_backend('ibm_montreal')
        
        # Get the noise characteristics
        noise_model = NoiseModel.from_backend(backend) # get the noise model
        coupling_map = backend.configuration().coupling_map # get the coupling map
        basis_gates = noise_model.basis_gates # get the basis gates
        
        # Initialize the noisy estimator for VQD
        noisy_estimator = AerEstimator(
        backend_options = {
            "coupling_map": coupling_map,
            "noise_model": noise_model,
            "basis_gates": basis_gates,
        },
        run_options = {"seed": 1, "shots": 3000},
        transpile_options = {"seed_transpiler": 1},
    )
        # Run the VQD algorithm
        vqd = VQD(estimator = noisy_estimator, fidelity = fidelity, ansatz = ansatz, optimizer = optimizer, \
                  k = k, initial_point = initial_point, callback = callback_noisy)
        result = vqd.compute_eigenvalues(operator = qub_hamiltonian)
        
        # Get the corresponding zeromode
        optimal_params = result.optimal_points
        zeromode_points = optimal_params[0]
        final_circuit = ansatz.assign_parameters(zeromode_points)
        zeromode_vqd = Statevector.from_instruction(final_circuit)
        
    return result.eigenvalues, optimal_params, zeromode_vqd, num_parameters

# %% [markdown]
# ## Running noiseless VQD on the Hermitian FPE operator matrix

# %%
eigenvalues, optimal_params, zeromode_vqd, num_parameters = run_VQD(matrix = matrix, k = 1, RealAmps = True, \
                                                                    bfgs = True, noise = False)

## Printing relevant results
# Print the eigenvalues
print('The eigenvalues obtained using VQD are:')
print(eigenvalues)
print()

# Print the optimal parameters
print('The optimal parameters of the variational ansatz for eigenvalue computations are:')
print(optimal_params)
print()

# Print the zeromode obtained
print('The zeromode obtained using the VQD algorithm is:')
print(zeromode_vqd)
print()

# Print the number of variational parameters
print('The number of variationa parameters being used is:')
print(num_parameters)
print()
# Out:
# INFO 2024-06-22 13:02:19,277 vqd.py:246] beta autoevaluated to 481527.5525822408
# WARNING 2024-06-22 13:02:19,284 p_bfgs.py:124] For Windows, using only current process. Multiple core use not supported.
# INFO 2024-06-22 13:02:27,742 vqd.py:317] Ground state optimization complete in 8.457790851593018 seconds.
# Found opt_params [[-1.56521573 -1.17882039  1.71334626  1.91572559  0.87075574 -0.26031095
#   -1.23498922  0.04365539 -0.63191827 -1.91725086 -1.72957481 -1.06663443
#   -2.60474608  1.07041484 -2.0862562 ]] in 784 evals
# The eigenvalues obtained using VQD are:
# [0.0057397+0.j]
#
# The optimal parameters of the variational ansatz for eigenvalue computations are:
# [[-1.56521573 -1.17882039  1.71334626  1.91572559  0.87075574 -0.26031095
#   -1.23498922  0.04365539 -0.63191827 -1.91725086 -1.72957481 -1.06663443
#   -2.60474608  1.07041484 -2.0862562 ]]
#
# The zeromode obtained using the VQD algorithm is:
# Statevector([-0.4744772 +0.j, -0.60869976+0.j, -0.55925987+0.j,
#              -0.29602894+0.j, -0.03873115+0.j,  0.04625381+0.j,
#               0.01489065+0.j, -0.00948656+0.j],
#             dims=(2, 2, 2))
#
# The number of variationa parameters being used is:
# 15

# %% [markdown]
# ## Compute the steady-state PDF using the obtained VQD zeromode

# %%
## Get the ground state PDF using the VQSVD zeromode
x_vqd, y_vqd = get_pdf(nmax, x, dx, L, shift, np.real(-zeromode_vqd), normalize = True, make_even = True)

# Compute the standard deviation of the distribution
deviation = np.sqrt(np.var(y_vqd))

# Compute the expectation value of x
x_expectation, x_square_expectation = get_expectation(x, y_vqd)

# Compute the skewness and kurtosis of the distribution
skewness = skew(y_vqd, bias = False)
kurtosis_val = kurtosis(y_vqd)

# Compute the moments of the distribution
quantum_moments = get_moments(y_vqd, moments)

# # Compute the quantum CDF
# cum_quantum = np.cumsum(y_vqd)
# cum_quantum = cum_quantum/cum_quantum[-1] # normalization

# Compute the mean and variance of the distribution
mean_dis = np.mean(y_vqd)
variance = np.var(y_vqd)

# Compute the absolute error percentage in estimating the mean and variance
error_mean = abs(mean_dis - np.mean(y)) * 100
error_variance = abs(variance - np.var(y)) * 100

## Print the relevant results
# Print the standard deviation
print('The standard deviation of the distribution is:')
print(deviation)
print()

# Print the expectation value
print('The expectation value of x is:')
print(x_expectation)
print()

# Print the expectation value of x^2
print('The expectation value of x^2 is:')
print(x_square_expectation)
print()

# Print the skewness of the distribution
print('The skewness of the distribution is:')
print(skewness)
print()

# Print the kurtosis of the distribution
print('The kurtosis of the distribution is:')
print(kurtosis_val)
print()

# Print the moments of the distribution
print('The moments of the distribution are:')
print(quantum_moments)
print()

# Print the mean
print('The mean of the PDF estimated using VQSVD is:')
print(mean_dis)
print()

# Print the variance
print('The variance of the PDF estimated using VQSVD is:')
print(variance)
print()

# Print the error in estimating the mean
print('The error in estimating the mean is (percentage):')
print(error_mean)
print()

# Print the error in estimating the variance
print('The error in estimating the variance is (percentage):')
print(error_variance)
print()

# Comparison between the ground state PDFs (on a log scale)
y_cutoff = 3 * 1e-4

# Extract the relevant results 
x_classical, y_classical = cutoff_graph(x, y, y_cutoff) # exact analytical solution
x_quantum, y_quantum = cutoff_graph(x, y_vqd, y_cutoff) # QPE (or VQSVD)

# Plot
fig, ax = plt.subplots(dpi = 600)

# Plot the first set of data on a log base 2 scale
ax.plot(x_classical, y_classical, color = 'r', label = 'Exact')

# # Plot the exact diagonalization results
# ax.plot(x_diag, y_diag, '--b', label = "Exact diagonalization")

# Plot the second set of data on a log base 2 scale
ax.plot(x_quantum, y_quantum, '--b', label = 'VQD')

# Set y-axis to a log scale
ax.set_yscale('log')

# Set labels and title
ax.set_xlabel('$x$', fontsize = 17)
ax.set_ylabel('$P(x)$', fontsize = 17)

# Show a legend
ax.legend()
# Out:
# The standard deviation of the distribution is:
# 0.10838887926663167
#
# The expectation value of x is:
# 6.767279039677146e-15
#
# The expectation value of x^2 is:
# 136.27119488334947
#
# The skewness of the distribution is:
# 2.0623032399820076
#
# The kurtosis of the distribution is:
# 2.903119061927338
#
# The moments of the distribution are:
# [0.0, 0.011748149148676458, 0.0026241024714977862, 0.00081474263950974, 0.00025018775303127153]
#
# The mean of the PDF estimated using VQSVD is:
# 0.04999999999999999
#
# The variance of the PDF estimated using VQSVD is:
# 0.011748149148676458
#
# The error in estimating the mean is (percentage):
# 0.00249999999986511
#
# The error in estimating the variance is (percentage):
# 0.005629404090593676

# %% [markdown]
# ## Run noisy VQD on the Hermitian FPE operator matrix

# %%
eigenvalues, optimal_params, zeromode_vqd, num_parameters = run_VQD(matrix = matrix, k = 1, RealAmps = False, \
                                                                    bfgs = False, noise = True)

## Printing relevant results
# Print the eigenvalues
print('The eigenvalues obtained using VQD are:')
print(eigenvalues)
print()

# Print the optimal parameters
print('The optimal parameters of the variational ansatz for eigenvalue computations are:')
print(optimal_params)
print()

# Print the zeromode obtained
print('The zeromode obtained using the VQD algorithm is:')
print(zeromode_vqd)
print()

# Print the number of variational parameters
print('The number of variationa parameters being used is:')
print(num_parameters)
print()
# Out:
# INFO 2024-06-22 13:03:59,647 vqd.py:246] beta autoevaluated to 481527.5525822408
# INFO 2024-06-22 13:03:59,647 spsa.py:321] SPSA: Starting calibration of learning rate and perturbation.
# INFO 2024-06-22 13:03:59,667 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,681 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,682 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,690 runningpassmanager.py:247] Pass: Unroll3qOrMore - 6.08659 (ms)
# INFO 2024-06-22 13:03:59,692 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,695 runningpassmanager.py:247] Pass: TrivialLayout - 0.93293 (ms)
# INFO 2024-06-22 13:03:59,697 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,700 runningpassmanager.py:247] Pass: FullAncillaAllocation - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,700 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,700 runningpassmanager.py:247] Pass: ApplyLayout - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,712 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,714 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,716 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,717 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 1.00327 (ms)
# INFO 2024-06-22 13:03:59,718 basis_translator.py:152] Begin BasisTranslator from source basis {('barrier', 3), ('ry', 1), ('rz', 1), ('measure', 1), ('cx', 2)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:03:59,718 basis_translator.py:202] Basis translation path search completed in 0.000s.
# INFO 2024-06-22 13:03:59,718 basis_translator.py:227] Basis translation paths composed in 0.000s.
# INFO 2024-06-22 13:03:59,735 basis_translator.py:278] Basis translation instructions replaced in 0.006s.
# INFO 2024-06-22 13:03:59,735 runningpassmanager.py:247] Pass: BasisTranslator - 16.63280 (ms)
# INFO 2024-06-22 13:03:59,744 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,746 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,747 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,748 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,750 runningpassmanager.py:247] Pass: FixedPoint - 0.99778 (ms)
# INFO 2024-06-22 13:03:59,752 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 2.02727 (ms)
# INFO 2024-06-22 13:03:59,760 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,762 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,763 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,764 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,765 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,766 runningpassmanager.py:247] Pass: FixedPoint - 0.99587 (ms)
# INFO 2024-06-22 13:03:59,768 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 1.04594 (ms)
# INFO 2024-06-22 13:03:59,768 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,768 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,768 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,768 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,768 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,778 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,779 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,781 transpiler.py:456] Total Transpile Time - 117.38968 (ms)
# INFO 2024-06-22 13:03:59,817 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,817 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,829 runningpassmanager.py:247] Pass: HighLevelSynthesis - 1.00231 (ms)
# INFO 2024-06-22 13:03:59,830 runningpassmanager.py:247] Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,831 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,833 runningpassmanager.py:247] Pass: FullAncillaAllocation - 1.00541 (ms)
# INFO 2024-06-22 13:03:59,835 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,837 runningpassmanager.py:247] Pass: ApplyLayout - 0.50521 (ms)
# INFO 2024-06-22 13:03:59,837 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,837 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,837 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,844 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,846 basis_translator.py:152] Begin BasisTranslator from source basis {('sdg', 1), ('measure', 1), ('h', 1)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:03:59,848 basis_translator.py:202] Basis translation path search completed in 0.001s.
# INFO 2024-06-22 13:03:59,851 basis_translator.py:227] Basis translation paths composed in 0.003s.
# INFO 2024-06-22 13:03:59,855 basis_translator.py:278] Basis translation instructions replaced in 0.000s.
# INFO 2024-06-22 13:03:59,855 runningpassmanager.py:247] Pass: BasisTranslator - 9.49574 (ms)
# INFO 2024-06-22 13:03:59,855 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,855 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,855 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,860 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,862 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,868 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 3.99494 (ms)
# INFO 2024-06-22 13:03:59,869 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,869 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,869 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,869 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,869 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,869 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,869 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,869 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,869 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,880 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,881 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,883 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,885 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,886 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,888 transpiler.py:456] Total Transpile Time - 71.42115 (ms)
# INFO 2024-06-22 13:03:59,902 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,902 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,902 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,902 runningpassmanager.py:247] Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,902 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,911 runningpassmanager.py:247] Pass: FullAncillaAllocation - 7.95960 (ms)
# INFO 2024-06-22 13:03:59,913 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 1.00136 (ms)
# INFO 2024-06-22 13:03:59,919 runningpassmanager.py:247] Pass: ApplyLayout - 4.49800 (ms)
# INFO 2024-06-22 13:03:59,919 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,919 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,919 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,919 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,919 basis_translator.py:152] Begin BasisTranslator from source basis {('sdg', 1), ('measure', 1), ('h', 1)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:03:59,919 basis_translator.py:202] Basis translation path search completed in 0.000s.
# INFO 2024-06-22 13:03:59,935 basis_translator.py:227] Basis translation paths composed in 0.007s.
# INFO 2024-06-22 13:03:59,936 basis_translator.py:278] Basis translation instructions replaced in 0.000s.
# INFO 2024-06-22 13:03:59,936 runningpassmanager.py:247] Pass: BasisTranslator - 16.91318 (ms)
# INFO 2024-06-22 13:03:59,936 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,936 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,936 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,936 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,936 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,946 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 10.01406 (ms)
# INFO 2024-06-22 13:03:59,947 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,948 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,950 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,950 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,950 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,950 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,950 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,950 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,961 runningpassmanager.py:247] Pass: GatesInBasis - 1.00470 (ms)
# INFO 2024-06-22 13:03:59,963 runningpassmanager.py:247] Pass: Depth - 0.99969 (ms)
# INFO 2024-06-22 13:03:59,963 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,964 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,965 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,965 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,966 transpiler.py:456] Total Transpile Time - 78.00770 (ms)
# INFO 2024-06-22 13:03:59,970 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,977 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,978 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,979 runningpassmanager.py:247] Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,980 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,981 runningpassmanager.py:247] Pass: FullAncillaAllocation - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,982 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,985 runningpassmanager.py:247] Pass: ApplyLayout - 1.70231 (ms)
# INFO 2024-06-22 13:03:59,985 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,985 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,985 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,985 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO 2024-06-22 13:03:59,985 basis_translator.py:152] Begin BasisTranslator from source basis {('sdg', 1), ('measure', 1), ('h', 1)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:03:59,995 basis_translator.py:202] Basis translation path search completed in 0.010s.
# INFO 2024-06-22 13:04:00,003 basis_translator.py:227] Basis translation paths composed in 0.006s.
# INFO 2024-06-22 13:04:00,003 basis_translator.py:278] Basis translation instructions replaced in 0.000s.
# INFO 2024-06-22 13:04:00,003 runningpassmanager.py:247] Pass: BasisTranslator - 17.81416 (ms)
# INFO 2024-06-22 13:04:00,003 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,010 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,012 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,013 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,014 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,018 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 2.01154 (ms)
# INFO 2024-06-22 13:04:00,020 runningpassmanager.py:247] Pass: CXCancellation - 1.00374 (ms)
# INFO 2024-06-22 13:04:00,022 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,022 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,028 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,029 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,030 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,032 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,034 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,035 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,037 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,037 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,037 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,037 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,037 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,045 transpiler.py:456] Total Transpile Time - 76.29013 (ms)
# INFO 2024-06-22 13:04:00,051 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,051 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,051 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,051 runningpassmanager.py:247] Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,051 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,060 runningpassmanager.py:247] Pass: FullAncillaAllocation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,062 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,065 runningpassmanager.py:247] Pass: ApplyLayout - 1.99795 (ms)
# INFO 2024-06-22 13:04:00,066 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,068 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,068 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,068 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,068 basis_translator.py:152] Begin BasisTranslator from source basis {('sdg', 1), ('measure', 1), ('h', 1)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:04:00,068 basis_translator.py:202] Basis translation path search completed in 0.000s.
# INFO 2024-06-22 13:04:00,084 basis_translator.py:227] Basis translation paths composed in 0.016s.
# INFO 2024-06-22 13:04:00,084 basis_translator.py:278] Basis translation instructions replaced in 0.000s.
# INFO 2024-06-22 13:04:00,084 runningpassmanager.py:247] Pass: BasisTranslator - 16.20936 (ms)
# INFO 2024-06-22 13:04:00,084 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,084 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,084 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,095 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,097 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,101 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 3.31354 (ms)
# INFO 2024-06-22 13:04:00,101 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,101 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,101 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,101 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,101 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,101 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,112 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 0.96869 (ms)
# INFO 2024-06-22 13:04:00,113 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,114 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,116 runningpassmanager.py:247] Pass: Depth - 1.00446 (ms)
# INFO 2024-06-22 13:04:00,117 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,119 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,119 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,119 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,119 transpiler.py:456] Total Transpile Time - 71.15412 (ms)
# INFO 2024-06-22 13:04:00,135 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,135 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,135 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,135 runningpassmanager.py:247] Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,135 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,135 runningpassmanager.py:247] Pass: FullAncillaAllocation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,135 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,147 runningpassmanager.py:247] Pass: ApplyLayout - 1.00088 (ms)
# INFO 2024-06-22 13:04:00,149 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,151 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,154 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,154 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,154 basis_translator.py:152] Begin BasisTranslator from source basis {('sdg', 1), ('measure', 1), ('h', 1)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:04:00,160 basis_translator.py:202] Basis translation path search completed in 0.007s.
# INFO 2024-06-22 13:04:00,166 basis_translator.py:227] Basis translation paths composed in 0.004s.
# INFO 2024-06-22 13:04:00,168 basis_translator.py:278] Basis translation instructions replaced in 0.001s.
# INFO 2024-06-22 13:04:00,169 runningpassmanager.py:247] Pass: BasisTranslator - 15.68294 (ms)
# INFO 2024-06-22 13:04:00,169 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,169 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,169 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,178 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,179 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,181 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 0.99826 (ms)
# INFO 2024-06-22 13:04:00,182 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,183 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,184 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,185 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,185 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,185 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,185 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,185 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,185 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,185 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,185 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,185 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,194 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,195 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,197 transpiler.py:456] Total Transpile Time - 77.90589 (ms)
# INFO 2024-06-22 13:04:00,201 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,201 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,201 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,201 runningpassmanager.py:247] Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,201 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,210 runningpassmanager.py:247] Pass: FullAncillaAllocation - 9.22775 (ms)
# INFO 2024-06-22 13:04:00,212 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 0.97847 (ms)
# INFO 2024-06-22 13:04:00,216 runningpassmanager.py:247] Pass: ApplyLayout - 2.99907 (ms)
# INFO 2024-06-22 13:04:00,217 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,217 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,217 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,217 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,227 basis_translator.py:152] Begin BasisTranslator from source basis {('sdg', 1), ('measure', 1), ('h', 1)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:04:00,231 basis_translator.py:202] Basis translation path search completed in 0.002s.
# INFO 2024-06-22 13:04:00,234 basis_translator.py:227] Basis translation paths composed in 0.001s.
# INFO 2024-06-22 13:04:00,234 basis_translator.py:278] Basis translation instructions replaced in 0.000s.
# INFO 2024-06-22 13:04:00,234 runningpassmanager.py:247] Pass: BasisTranslator - 6.77657 (ms)
# INFO 2024-06-22 13:04:00,234 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,234 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,234 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,234 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,245 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,248 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 1.00040 (ms)
# INFO 2024-06-22 13:04:00,249 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,250 runningpassmanager.py:247] Pass: GatesInBasis - 0.99397 (ms)
# INFO 2024-06-22 13:04:00,250 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,251 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,252 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,253 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,253 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,253 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,253 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,253 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,260 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,262 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,263 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,264 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,266 transpiler.py:456] Total Transpile Time - 68.68339 (ms)
# INFO 2024-06-22 13:04:00,268 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,279 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,281 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,282 runningpassmanager.py:247] Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,284 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,285 runningpassmanager.py:247] Pass: FullAncillaAllocation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,285 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,285 runningpassmanager.py:247] Pass: ApplyLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,285 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,285 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,285 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,296 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,297 basis_translator.py:152] Begin BasisTranslator from source basis {('measure', 1), ('h', 1)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:04:00,300 basis_translator.py:202] Basis translation path search completed in 0.002s.
# INFO 2024-06-22 13:04:00,302 basis_translator.py:227] Basis translation paths composed in 0.000s.
# INFO 2024-06-22 13:04:00,302 basis_translator.py:278] Basis translation instructions replaced in 0.000s.
# INFO 2024-06-22 13:04:00,302 runningpassmanager.py:247] Pass: BasisTranslator - 5.09119 (ms)
# INFO 2024-06-22 13:04:00,302 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,313 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,314 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,315 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,316 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,319 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 1.12033 (ms)
# INFO 2024-06-22 13:04:00,319 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,319 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,319 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,319 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,319 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,328 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,329 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,330 transpiler.py:456] Total Transpile Time - 62.03270 (ms)
# INFO 2024-06-22 13:04:00,337 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,344 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,346 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,348 runningpassmanager.py:247] Pass: Unroll3qOrMore - 1.00613 (ms)
# INFO 2024-06-22 13:04:00,349 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,351 runningpassmanager.py:247] Pass: FullAncillaAllocation - 1.00112 (ms)
# INFO 2024-06-22 13:04:00,352 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,352 runningpassmanager.py:247] Pass: ApplyLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,352 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,352 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,362 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,363 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,365 basis_translator.py:152] Begin BasisTranslator from source basis {('measure', 1), ('h', 1)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:04:00,367 basis_translator.py:202] Basis translation path search completed in 0.000s.
# INFO 2024-06-22 13:04:00,367 basis_translator.py:227] Basis translation paths composed in 0.000s.
# INFO 2024-06-22 13:04:00,367 basis_translator.py:278] Basis translation instructions replaced in 0.000s.
# INFO 2024-06-22 13:04:00,367 runningpassmanager.py:247] Pass: BasisTranslator - 2.03252 (ms)
# INFO 2024-06-22 13:04:00,377 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 9.69505 (ms)
# INFO 2024-06-22 13:04:00,379 runningpassmanager.py:247] Pass: Depth - 0.99111 (ms)
# INFO 2024-06-22 13:04:00,380 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,381 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,382 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,385 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 1.99986 (ms)
# INFO 2024-06-22 13:04:00,386 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,386 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,386 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,386 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,386 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,395 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,397 runningpassmanager.py:247] Pass: ContainsInstruction - 1.00470 (ms)
# INFO 2024-06-22 13:04:00,398 transpiler.py:456] Total Transpile Time - 65.58418 (ms)
# INFO 2024-06-22 13:04:00,402 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,412 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,414 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,415 runningpassmanager.py:247] Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,416 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,416 runningpassmanager.py:247] Pass: FullAncillaAllocation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,416 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,416 runningpassmanager.py:247] Pass: ApplyLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,428 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,430 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,432 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,434 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,434 basis_translator.py:152] Begin BasisTranslator from source basis {('measure', 1), ('h', 1)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:04:00,434 basis_translator.py:202] Basis translation path search completed in 0.000s.
# INFO 2024-06-22 13:04:00,434 basis_translator.py:227] Basis translation paths composed in 0.000s.
# INFO 2024-06-22 13:04:00,445 basis_translator.py:278] Basis translation instructions replaced in 0.001s.
# INFO 2024-06-22 13:04:00,446 runningpassmanager.py:247] Pass: BasisTranslator - 12.33363 (ms)
# INFO 2024-06-22 13:04:00,447 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,448 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,449 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,451 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,452 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,452 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,452 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,452 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,452 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,452 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,452 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,452 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,452 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,462 transpiler.py:456] Total Transpile Time - 62.64329 (ms)
# INFO 2024-06-22 13:04:00,468 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,468 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,480 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,481 runningpassmanager.py:247] Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,483 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,484 runningpassmanager.py:247] Pass: FullAncillaAllocation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,484 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,484 runningpassmanager.py:247] Pass: ApplyLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,494 runningpassmanager.py:247] Pass: CheckMap - 9.65977 (ms)
# INFO 2024-06-22 13:04:00,496 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,498 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,500 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 1.00040 (ms)
# INFO 2024-06-22 13:04:00,501 basis_translator.py:152] Begin BasisTranslator from source basis {('measure', 1), ('h', 1)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:04:00,502 basis_translator.py:202] Basis translation path search completed in 0.000s.
# INFO 2024-06-22 13:04:00,502 basis_translator.py:227] Basis translation paths composed in 0.000s.
# INFO 2024-06-22 13:04:00,502 basis_translator.py:278] Basis translation instructions replaced in 0.000s.
# INFO 2024-06-22 13:04:00,502 runningpassmanager.py:247] Pass: BasisTranslator - 1.16587 (ms)
# INFO 2024-06-22 13:04:00,511 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,513 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,515 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,516 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,519 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,520 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,520 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,520 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,527 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,529 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,530 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,532 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,534 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,535 transpiler.py:456] Total Transpile Time - 71.89536 (ms)
# INFO 2024-06-22 13:04:00,546 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,548 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,549 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,551 runningpassmanager.py:247] Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,551 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,551 runningpassmanager.py:247] Pass: FullAncillaAllocation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,551 runningpassmanager.py:247] Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,561 runningpassmanager.py:247] Pass: ApplyLayout - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,562 runningpassmanager.py:247] Pass: CheckMap - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,563 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,563 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,564 runningpassmanager.py:247] Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,564 basis_translator.py:152] Begin BasisTranslator from source basis {('measure', 1), ('h', 1)} to target basis {'set_statevector', 'reset', 'roerror', 'while_loop', 'save_unitary', 'rz', 'delay', 'set_matrix_product_state', 'save_matrix_product_state', 'qerror_loc', 'for_loop', 'save_expval', 'save_amplitudes', 'save_statevector', 'save_probabilities_dict', 'measure', 'sx', 'if_else', 'set_superop', 'save_clifford', 'save_state', 'break_loop', 'save_density_matrix', 'save_statevector_dict', 'save_amplitudes_sq', 'x', 'quantum_channel', 'id', 'save_probabilities', 'set_density_matrix', 'save_superop', 'set_stabilizer', 'set_unitary', 'superop', 'save_expval_var', 'save_stabilizer', 'barrier', 'cx', 'snapshot', 'continue_loop', 'kraus'}.
# INFO 2024-06-22 13:04:00,566 basis_translator.py:202] Basis translation path search completed in 0.001s.
# INFO 2024-06-22 13:04:00,569 basis_translator.py:227] Basis translation paths composed in 0.003s.
# INFO 2024-06-22 13:04:00,569 basis_translator.py:278] Basis translation instructions replaced in 0.000s.
# INFO 2024-06-22 13:04:00,569 runningpassmanager.py:247] Pass: BasisTranslator - 5.07188 (ms)
# INFO 2024-06-22 13:04:00,569 runningpassmanager.py:247] Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,569 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,569 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,569 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,577 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,579 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 0.97775 (ms)
# INFO 2024-06-22 13:04:00,579 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,580 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,580 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,581 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,583 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,584 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,586 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,586 transpiler.py:456] Total Transpile Time - 50.66752 (ms)
# INFO 2024-06-22 13:04:00,600 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,600 runningpassmanager.py:247] Pass: UnitarySynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,600 runningpassmanager.py:247] Pass: HighLevelSynthesis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,600 runningpassmanager.py:247] Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,600 runningpassmanager.py:247] Pass: SetLayout - 0.00000 (ms)
# ...
# INFO 2024-06-22 13:04:00,770 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,770 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,777 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,779 runningpassmanager.py:247] Pass: Optimize1qGatesDecomposition - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,779 runningpassmanager.py:247] Pass: CXCancellation - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,780 runningpassmanager.py:247] Pass: GatesInBasis - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,781 runningpassmanager.py:247] Pass: Depth - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,781 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,782 runningpassmanager.py:247] Pass: Size - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,783 runningpassmanager.py:247] Pass: FixedPoint - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,785 runningpassmanager.py:247] Pass: ContainsInstruction - 0.00000 (ms)
# INFO 2024-06-22 13:04:00,785 transpiler.py:456] Total Transpile Time - 47.65129 (ms)
# INFO 2024-06-22 13:04:38,476 spsa.py:354] Finished calibration:
# INFO 2024-06-22 13:04:38,486 spsa.py:355]  -- Learning rate: a / ((A + n) ^ alpha) with a = 6.431923679128645e-05, A = 0, alpha = 0.602
# INFO 2024-06-22 13:04:38,486 spsa.py:361]  -- Perturbation: c / (n ^ gamma) with c = 0.2, gamma = 0.101
# INFO 2024-06-22 13:04:38,486 spsa.py:545] SPSA: Starting optimization.
# INFO 2024-06-22 13:04:39,904 spsa.py:595] Iteration 1/151 done in 1.4175138473510742.
# INFO 2024-06-22 13:04:41,274 spsa.py:595] Iteration 2/151 done in 1.370462417602539.
# INFO 2024-06-22 13:04:42,685 spsa.py:595] Iteration 3/151 done in 1.410527229309082.
# INFO 2024-06-22 13:04:43,845 spsa.py:595] Iteration 4/151 done in 1.1597020626068115.
# INFO 2024-06-22 13:04:45,325 spsa.py:595] Iteration 5/151 done in 1.4698154926300049.
# INFO 2024-06-22 13:04:46,777 spsa.py:595] Iteration 6/151 done in 1.4517569541931152.
# INFO 2024-06-22 13:04:48,165 spsa.py:595] Iteration 7/151 done in 1.388031244277954.
# INFO 2024-06-22 13:04:49,517 spsa.py:595] Iteration 8/151 done in 1.3522119522094727.
# INFO 2024-06-22 13:04:50,865 spsa.py:595] Iteration 9/151 done in 1.3466744422912598.
# INFO 2024-06-22 13:04:51,976 spsa.py:595] Iteration 10/151 done in 1.110809087753296.
# INFO 2024-06-22 13:04:53,425 spsa.py:595] Iteration 11/151 done in 1.4493327140808105.
# INFO 2024-06-22 13:04:54,797 spsa.py:595] Iteration 12/151 done in 1.3720014095306396.
# INFO 2024-06-22 13:04:56,194 spsa.py:595] Iteration 13/151 done in 1.3975062370300293.
# INFO 2024-06-22 13:04:57,748 spsa.py:595] Iteration 14/151 done in 1.5533788204193115.
# INFO 2024-06-22 13:04:59,162 spsa.py:595] Iteration 15/151 done in 1.4137003421783447.
# INFO 2024-06-22 13:05:00,268 spsa.py:595] Iteration 16/151 done in 1.1063950061798096.
# INFO 2024-06-22 13:05:01,607 spsa.py:595] Iteration 17/151 done in 1.338756799697876.
# INFO 2024-06-22 13:05:02,988 spsa.py:595] Iteration 18/151 done in 1.3809034824371338.
# INFO 2024-06-22 13:05:04,327 spsa.py:595] Iteration 19/151 done in 1.3397572040557861.
# INFO 2024-06-22 13:05:05,850 spsa.py:595] Iteration 20/151 done in 1.522273302078247.
# INFO 2024-06-22 13:05:07,300 spsa.py:595] Iteration 21/151 done in 1.450563907623291.
# INFO 2024-06-22 13:05:08,627 spsa.py:595] Iteration 22/151 done in 1.3272428512573242.
# INFO 2024-06-22 13:05:10,168 spsa.py:595] Iteration 23/151 done in 1.5410380363464355.
# INFO 2024-06-22 13:05:11,637 spsa.py:595] Iteration 24/151 done in 1.4687891006469727.
# INFO 2024-06-22 13:05:13,001 spsa.py:595] Iteration 25/151 done in 1.3635549545288086.
# INFO 2024-06-22 13:05:14,624 spsa.py:595] Iteration 26/151 done in 1.62312650680542.
# INFO 2024-06-22 13:05:16,040 spsa.py:595] Iteration 27/151 done in 1.4164254665374756.
# INFO 2024-06-22 13:05:17,433 spsa.py:595] Iteration 28/151 done in 1.393038034439087.
# INFO 2024-06-22 13:05:18,947 spsa.py:595] Iteration 29/151 done in 1.5133185386657715.
# INFO 2024-06-22 13:05:20,351 spsa.py:595] Iteration 30/151 done in 1.404402732849121.
# INFO 2024-06-22 13:05:21,819 spsa.py:595] Iteration 31/151 done in 1.467475175857544.
# INFO 2024-06-22 13:05:23,227 spsa.py:595] Iteration 32/151 done in 1.4080917835235596.
# INFO 2024-06-22 13:05:24,627 spsa.py:595] Iteration 33/151 done in 1.3999004364013672.
# INFO 2024-06-22 13:05:25,757 spsa.py:595] Iteration 34/151 done in 1.128962516784668.
# INFO 2024-06-22 13:05:27,144 spsa.py:595] Iteration 35/151 done in 1.3776397705078125.
# INFO 2024-06-22 13:05:28,548 spsa.py:595] Iteration 36/151 done in 1.403651237487793.
# INFO 2024-06-22 13:05:30,030 spsa.py:595] Iteration 37/151 done in 1.481882095336914.
# INFO 2024-06-22 13:05:31,416 spsa.py:595] Iteration 38/151 done in 1.3868193626403809.
# INFO 2024-06-22 13:05:32,904 spsa.py:595] Iteration 39/151 done in 1.4878239631652832.
# INFO 2024-06-22 13:05:34,170 spsa.py:595] Iteration 40/151 done in 1.2653753757476807.
# INFO 2024-06-22 13:05:35,570 spsa.py:595] Iteration 41/151 done in 1.3998281955718994.
# INFO 2024-06-22 13:05:36,969 spsa.py:595] Iteration 42/151 done in 1.398862600326538.
# INFO 2024-06-22 13:05:38,272 spsa.py:595] Iteration 43/151 done in 1.3025615215301514.
# INFO 2024-06-22 13:05:39,690 spsa.py:595] Iteration 44/151 done in 1.416912317276001.
# INFO 2024-06-22 13:05:41,006 spsa.py:595] Iteration 45/151 done in 1.315798044204712.
# INFO 2024-06-22 13:05:42,066 spsa.py:595] Iteration 46/151 done in 1.0600802898406982.
# INFO 2024-06-22 13:05:43,448 spsa.py:595] Iteration 47/151 done in 1.3820087909698486.
# INFO 2024-06-22 13:05:44,939 spsa.py:595] Iteration 48/151 done in 1.481041431427002.
# INFO 2024-06-22 13:05:46,371 spsa.py:595] Iteration 49/151 done in 1.4317491054534912.
# INFO 2024-06-22 13:05:47,722 spsa.py:595] Iteration 50/151 done in 1.3502283096313477.
# INFO 2024-06-22 13:05:49,102 spsa.py:595] Iteration 51/151 done in 1.380004644393921.
# INFO 2024-06-22 13:05:50,189 spsa.py:595] Iteration 52/151 done in 1.0867407321929932.
# INFO 2024-06-22 13:05:51,579 spsa.py:595] Iteration 53/151 done in 1.3900799751281738.
# INFO 2024-06-22 13:05:52,940 spsa.py:595] Iteration 54/151 done in 1.3613858222961426.
# INFO 2024-06-22 13:05:54,322 spsa.py:595] Iteration 55/151 done in 1.3817799091339111.
# INFO 2024-06-22 13:05:55,777 spsa.py:595] Iteration 56/151 done in 1.455148696899414.
# INFO 2024-06-22 13:05:57,280 spsa.py:595] Iteration 57/151 done in 1.5028700828552246.
# INFO 2024-06-22 13:05:58,472 spsa.py:595] Iteration 58/151 done in 1.1917922496795654.
# INFO 2024-06-22 13:05:59,771 spsa.py:595] Iteration 59/151 done in 1.2997639179229736.
# INFO 2024-06-22 13:06:01,205 spsa.py:595] Iteration 60/151 done in 1.4334392547607422.
# INFO 2024-06-22 13:06:02,608 spsa.py:595] Iteration 61/151 done in 1.3928697109222412.
# INFO 2024-06-22 13:06:04,035 spsa.py:595] Iteration 62/151 done in 1.4170362949371338.
# INFO 2024-06-22 13:06:05,362 spsa.py:595] Iteration 63/151 done in 1.3166508674621582.
# INFO 2024-06-22 13:06:06,521 spsa.py:595] Iteration 64/151 done in 1.15995192527771.
# INFO 2024-06-22 13:06:07,894 spsa.py:595] Iteration 65/151 done in 1.3726263046264648.
# INFO 2024-06-22 13:06:09,255 spsa.py:595] Iteration 66/151 done in 1.3604090213775635.
# INFO 2024-06-22 13:06:10,651 spsa.py:595] Iteration 67/151 done in 1.39674711227417.
# INFO 2024-06-22 13:06:12,082 spsa.py:595] Iteration 68/151 done in 1.4305179119110107.
# INFO 2024-06-22 13:06:13,564 spsa.py:595] Iteration 69/151 done in 1.4824588298797607.
# INFO 2024-06-22 13:06:14,795 spsa.py:595] Iteration 70/151 done in 1.2309367656707764.
# INFO 2024-06-22 13:06:16,295 spsa.py:595] Iteration 71/151 done in 1.499436378479004.
# INFO 2024-06-22 13:06:17,867 spsa.py:595] Iteration 72/151 done in 1.5728352069854736.
# INFO 2024-06-22 13:06:19,277 spsa.py:595] Iteration 73/151 done in 1.4100263118743896.
# INFO 2024-06-22 13:06:20,648 spsa.py:595] Iteration 74/151 done in 1.3708536624908447.
# INFO 2024-06-22 13:06:21,987 spsa.py:595] Iteration 75/151 done in 1.3389129638671875.
# INFO 2024-06-22 13:06:23,157 spsa.py:595] Iteration 76/151 done in 1.1698696613311768.
# INFO 2024-06-22 13:06:24,557 spsa.py:595] Iteration 77/151 done in 1.3901433944702148.
# INFO 2024-06-22 13:06:26,064 spsa.py:595] Iteration 78/151 done in 1.5065264701843262.
# INFO 2024-06-22 13:06:27,548 spsa.py:595] Iteration 79/151 done in 1.4841792583465576.
# INFO 2024-06-22 13:06:29,038 spsa.py:595] Iteration 80/151 done in 1.489945650100708.
# INFO 2024-06-22 13:06:30,571 spsa.py:595] Iteration 81/151 done in 1.5331354141235352.
# INFO 2024-06-22 13:06:31,733 spsa.py:595] Iteration 82/151 done in 1.161987543106079.
# INFO 2024-06-22 13:06:33,171 spsa.py:595] Iteration 83/151 done in 1.4380874633789062.
# INFO 2024-06-22 13:06:34,490 spsa.py:595] Iteration 84/151 done in 1.3189656734466553.
# INFO 2024-06-22 13:06:35,901 spsa.py:595] Iteration 85/151 done in 1.410884141921997.
# INFO 2024-06-22 13:06:37,354 spsa.py:595] Iteration 86/151 done in 1.4525678157806396.
# INFO 2024-06-22 13:06:38,783 spsa.py:595] Iteration 87/151 done in 1.4296176433563232.
# INFO 2024-06-22 13:06:39,963 spsa.py:595] Iteration 88/151 done in 1.1700739860534668.
# INFO 2024-06-22 13:06:41,390 spsa.py:595] Iteration 89/151 done in 1.4265787601470947.
# INFO 2024-06-22 13:06:42,845 spsa.py:595] Iteration 90/151 done in 1.4454236030578613.
# INFO 2024-06-22 13:06:44,203 spsa.py:595] Iteration 91/151 done in 1.3582043647766113.
# INFO 2024-06-22 13:06:45,653 spsa.py:595] Iteration 92/151 done in 1.449697732925415.
# INFO 2024-06-22 13:06:46,966 spsa.py:595] Iteration 93/151 done in 1.3129830360412598.
# INFO 2024-06-22 13:06:48,124 spsa.py:595] Iteration 94/151 done in 1.1581370830535889.
# INFO 2024-06-22 13:06:49,533 spsa.py:595] Iteration 95/151 done in 1.4084956645965576.
# INFO 2024-06-22 13:06:50,963 spsa.py:595] Iteration 96/151 done in 1.4300286769866943.
# INFO 2024-06-22 13:06:52,325 spsa.py:595] Iteration 97/151 done in 1.3618338108062744.
# INFO 2024-06-22 13:06:53,766 spsa.py:595] Iteration 98/151 done in 1.4411358833312988.
# INFO 2024-06-22 13:06:55,186 spsa.py:595] Iteration 99/151 done in 1.42002272605896.
# INFO 2024-06-22 13:06:56,338 spsa.py:595] Iteration 100/151 done in 1.1525251865386963.
# INFO 2024-06-22 13:06:57,852 spsa.py:595] Iteration 101/151 done in 1.5039732456207275.
# INFO 2024-06-22 13:06:59,317 spsa.py:595] Iteration 102/151 done in 1.4649837017059326.
# INFO 2024-06-22 13:07:00,799 spsa.py:595] Iteration 103/151 done in 1.4820563793182373.
# INFO 2024-06-22 13:07:02,239 spsa.py:595] Iteration 104/151 done in 1.4396007061004639.
# INFO 2024-06-22 13:07:03,639 spsa.py:595] Iteration 105/151 done in 1.4000754356384277.
# INFO 2024-06-22 13:07:04,745 spsa.py:595] Iteration 106/151 done in 1.0964324474334717.
# INFO 2024-06-22 13:07:06,120 spsa.py:595] Iteration 107/151 done in 1.374861717224121.
# INFO 2024-06-22 13:07:07,549 spsa.py:595] Iteration 108/151 done in 1.428375005722046.
# INFO 2024-06-22 13:07:09,062 spsa.py:595] Iteration 109/151 done in 1.5134029388427734.
# INFO 2024-06-22 13:07:10,519 spsa.py:595] Iteration 110/151 done in 1.456542730331421.
# INFO 2024-06-22 13:07:11,873 spsa.py:595] Iteration 111/151 done in 1.3544743061065674.
# INFO 2024-06-22 13:07:12,998 spsa.py:595] Iteration 112/151 done in 1.12522554397583.
# INFO 2024-06-22 13:07:14,382 spsa.py:595] Iteration 113/151 done in 1.38350248336792.
# INFO 2024-06-22 13:07:15,756 spsa.py:595] Iteration 114/151 done in 1.3743133544921875.
# INFO 2024-06-22 13:07:17,141 spsa.py:595] Iteration 115/151 done in 1.3852283954620361.
# INFO 2024-06-22 13:07:18,655 spsa.py:595] Iteration 116/151 done in 1.5133154392242432.
# INFO 2024-06-22 13:07:20,078 spsa.py:595] Iteration 117/151 done in 1.4234235286712646.
# INFO 2024-06-22 13:07:21,158 spsa.py:595] Iteration 118/151 done in 1.0798346996307373.
# INFO 2024-06-22 13:07:22,652 spsa.py:595] Iteration 119/151 done in 1.4944572448730469.
# INFO 2024-06-22 13:07:24,074 spsa.py:595] Iteration 120/151 done in 1.4220547676086426.
# INFO 2024-06-22 13:07:25,418 spsa.py:595] Iteration 121/151 done in 1.3433046340942383.
# INFO 2024-06-22 13:07:26,802 spsa.py:595] Iteration 122/151 done in 1.38429594039917.
# INFO 2024-06-22 13:07:28,194 spsa.py:595] Iteration 123/151 done in 1.3823096752166748.
# INFO 2024-06-22 13:07:29,314 spsa.py:595] Iteration 124/151 done in 1.1198172569274902.
# INFO 2024-06-22 13:07:30,894 spsa.py:595] Iteration 125/151 done in 1.579904556274414.
# INFO 2024-06-22 13:07:32,301 spsa.py:595] Iteration 126/151 done in 1.396730899810791.
# INFO 2024-06-22 13:07:33,688 spsa.py:595] Iteration 127/151 done in 1.3775408267974854.
# INFO 2024-06-22 13:07:35,067 spsa.py:595] Iteration 128/151 done in 1.3789591789245605.
# INFO 2024-06-22 13:07:36,413 spsa.py:595] Iteration 129/151 done in 1.3462026119232178.
# INFO 2024-06-22 13:07:37,614 spsa.py:595] Iteration 130/151 done in 1.2003729343414307.
# INFO 2024-06-22 13:07:39,074 spsa.py:595] Iteration 131/151 done in 1.4602084159851074.
# INFO 2024-06-22 13:07:40,548 spsa.py:595] Iteration 132/151 done in 1.4742038249969482.
# INFO 2024-06-22 13:07:42,088 spsa.py:595] Iteration 133/151 done in 1.5298383235931396.
# INFO 2024-06-22 13:07:43,475 spsa.py:595] Iteration 134/151 done in 1.3866004943847656.
# INFO 2024-06-22 13:07:44,879 spsa.py:595] Iteration 135/151 done in 1.4040465354919434.
# INFO 2024-06-22 13:07:46,105 spsa.py:595] Iteration 136/151 done in 1.2259747982025146.
# INFO 2024-06-22 13:07:47,458 spsa.py:595] Iteration 137/151 done in 1.3530676364898682.
# INFO 2024-06-22 13:07:48,867 spsa.py:595] Iteration 138/151 done in 1.4088826179504395.
# INFO 2024-06-22 13:07:50,264 spsa.py:595] Iteration 139/151 done in 1.3974769115447998.
# INFO 2024-06-22 13:07:51,699 spsa.py:595] Iteration 140/151 done in 1.4329371452331543.
# INFO 2024-06-22 13:07:53,080 spsa.py:595] Iteration 141/151 done in 1.3709592819213867.
# INFO 2024-06-22 13:07:54,270 spsa.py:595] Iteration 142/151 done in 1.1896476745605469.
# INFO 2024-06-22 13:07:55,710 spsa.py:595] Iteration 143/151 done in 1.4401204586029053.
# INFO 2024-06-22 13:07:57,143 spsa.py:595] Iteration 144/151 done in 1.4334516525268555.
# INFO 2024-06-22 13:07:58,540 spsa.py:595] Iteration 145/151 done in 1.3952827453613281.
# INFO 2024-06-22 13:08:00,001 spsa.py:595] Iteration 146/151 done in 1.4615907669067383.
# INFO 2024-06-22 13:08:01,446 spsa.py:595] Iteration 147/151 done in 1.44354248046875.
# INFO 2024-06-22 13:08:02,765 spsa.py:595] Iteration 148/151 done in 1.3178527355194092.
# INFO 2024-06-22 13:08:04,296 spsa.py:595] Iteration 149/151 done in 1.5304577350616455.
# INFO 2024-06-22 13:08:05,853 spsa.py:595] Iteration 150/151 done in 1.5566139221191406.
# INFO 2024-06-22 13:08:05,853 spsa.py:630] SPSA: Finished in 207.36651229858398
# INFO 2024-06-22 13:08:06,490 vqd.py:317] Ground state optimization complete in 246.83252215385437 seconds.
# Found opt_params [[ 1.14099237 -0.19122633 -3.02407259  3.54357942 -2.78408592  0.90780046
#    3.44853746 -3.64188633  1.6664097  -1.3277509   1.25625213 -0.16900763
#   -2.77384941 -2.92587534  2.35692104 -0.45600784  3.17148801 -0.85259013
#   -2.96612029  0.23194631 -0.89581623 -1.39496354 -1.22382414 -1.2918426
#    0.51280469  1.37800417 -2.88026632 -1.99199734 -0.35136175 -2.51629833]] in 351 evals
# The eigenvalues obtained using VQD are:
# [-6387.70785623+0.j]
#
# The optimal parameters of the variational ansatz for eigenvalue computations are:
# [[ 1.14099237 -0.19122633 -3.02407259  3.54357942 -2.78408592  0.90780046
#    3.44853746 -3.64188633  1.6664097  -1.3277509   1.25625213 -0.16900763
#   -2.77384941 -2.92587534  2.35692104 -0.45600784  3.17148801 -0.85259013
#   -2.96612029  0.23194631 -0.89581623 -1.39496354 -1.22382414 -1.2918426
#    0.51280469  1.37800417 -2.88026632 -1.99199734 -0.35136175 -2.51629833]]
#
# The zeromode obtained using the VQD algorithm is:
# Statevector([ 0.31257687-0.03251182j, -0.06264199+0.4834068j ,
#               0.2237866 -0.09307031j,  0.02722276+0.33169849j,
#               0.29257008+0.20029775j,  0.01405484+0.5012566j ,
#               0.24840818+0.04844045j,  0.12949718+0.19007961j],
#             dims=(2, 2, 2))
#
# The number of variationa parameters being used is:
# 30

# %% [markdown]
# ## Compute the steady-state PDF

# %%
## Get the ground state PDF using the VQD zeromode
x_vqd_noisy, y_vqd_noisy = get_pdf(nmax, x, dx, L, shift, np.real(zeromode_vqd), normalize = True, make_even = True)

# Comparison between the ground state PDFs (on a log scale)
y_cutoff = 3 * 1e-4

# Extract the relevant results 
x_quantum_noisy, y_quantum_noisy = cutoff_graph(x, y_vqd_noisy, y_cutoff) # VQD

# %% [markdown]
# ## Visualization

# %%
fig, ax = plt.subplots(dpi = 600)

ax.plot(x_classical, y_classical, color = 'k', linewidth = 2, label = 'Exact')
ax.plot(x_quantum, y_quantum, '--y', label = 'Noiseless VQD')
ax.plot(x_quantum_noisy, y_quantum_noisy, '--b', label = 'Noisy VQD')

# Set y-axis to a log scale
ax.set_yscale('log')

# Set labels and title
ax.set_xlabel('$x$', fontsize = 17)
ax.set_ylabel('$P(x)$', fontsize = 17)

# Show a legend
ax.legend(loc = 'best')
